# %%
# computes metrics for comparing the full RBC volumetric predictions with GT

# %%
# %env CUDA_VISIBLE_DEVICES=1
# %load_ext autoreload
# %autoreload 2
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib
from utils.utils import  load_data, train_test_auc, get_path

# %%
root_path = get_path()
fig_path = os.path.join(root_path, "figures")

# %% [markdown]
# # Evaluation of cellpose predictions on RBCs

# %%
target_dir = os.path.join(root_path, "RBC_labelled/")

# %%
cmap = matplotlib.cm.get_cmap("tab10")
thresholds = np.arange(11)/ 10
stitch_threshold = 0.1
n_folds = 10
anisotropy = 3.2

# %% [markdown]
# # 2D training

# %% [markdown]
# ## valid1

# %%
dataset = "valid1"
cv_model_names =["cellpose_data_valid1_by_stack_mode_2D_min_train_masks_0_seed_0_epoch_499",
                 "cellpose_data_valid1_valid2_valid3_by_stack_mode_2D_min_train_masks_0_seed_0_epoch_499"
                 ]
train_test_auc(cv_model_names, target_dir, dataset,  thresholds=thresholds,
               n_folds=n_folds, stitch_threshold=stitch_threshold, anisotropy=anisotropy)
# Out:
# Best method: cellpose_data_valid1_valid2_valid3_by_stack_mode_2D_min_train_masks_0_seed_0_epoch_499
# Best AUC: 0.6571303948576676
# <AxesSubplot:>

# %% [markdown]
# ## valid2

# %%
dataset = "valid2"
cv_model_names =["cellpose_data_valid2_by_stack_mode_2D_min_train_masks_0_seed_0_epoch_499",
                 "cellpose_data_valid1_valid2_valid3_by_stack_mode_2D_min_train_masks_0_seed_0_epoch_499"
                 ]
train_test_auc(cv_model_names, target_dir, dataset,  thresholds=thresholds,
               n_folds=n_folds, stitch_threshold=stitch_threshold, anisotropy=anisotropy)
# Out:
# Best method: cellpose_data_valid1_valid2_valid3_by_stack_mode_2D_min_train_masks_0_seed_0_epoch_499
# Best AUC: 0.666541305916306
# <AxesSubplot:>

# %% [markdown]
# ## valid3

# %%
dataset = "valid3"
cv_model_names =["cellpose_data_valid3_by_stack_mode_2D_min_train_masks_0_seed_0_epoch_499",
                 "cellpose_data_valid1_valid2_valid3_by_stack_mode_2D_min_train_masks_0_seed_0_epoch_499"
                 ]
train_test_auc(cv_model_names, target_dir, dataset,  thresholds=thresholds,
               n_folds=n_folds, stitch_threshold=stitch_threshold, anisotropy=anisotropy)
# Out:
# Best method: cellpose_data_valid1_valid2_valid3_by_stack_mode_2D_min_train_masks_0_seed_0_epoch_499
# Best AUC: 0.7238239538239539
# <AxesSubplot:>

# %%
# joint datasets
dataset = ["valid1", "valid2", "valid3"]

cv_model_names =["cellpose_data_valid1_valid2_valid3_by_stack_mode_2D_min_train_masks_0_seed_0_epoch_499"
                 ]
train_test_auc(cv_model_names, target_dir, dataset,  thresholds=thresholds,
               n_folds=n_folds, stitch_threshold=stitch_threshold, anisotropy=anisotropy)
# Out:
# Best method: cellpose_data_valid1_valid2_valid3_by_stack_mode_2D_min_train_masks_0_seed_0_epoch_499
# Best AUC: 0.6682824054552949
# <AxesSubplot:>

# %% [markdown]
# # 3D

# %% [markdown]
# ## valid1

# %%
dataset = "valid1"
cv_model_names =["cellpose_data_valid1_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499",
                 "cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499"
                 ]
train_test_auc(cv_model_names, target_dir, dataset,  thresholds=thresholds,
               n_folds=n_folds, stitch_threshold=stitch_threshold, anisotropy=anisotropy)
# Out:
# Best method: cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499
# Best AUC: 0.8412682014954741
# <AxesSubplot:>

# %% [markdown]
# ## valid2

# %%
dataset = "valid2"
cv_model_names =["cellpose_data_valid2_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499",
                 "cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499"
                 ]
train_test_auc(cv_model_names, target_dir, dataset,  thresholds=thresholds,
               n_folds=n_folds, stitch_threshold=stitch_threshold, anisotropy=anisotropy)
# Out:
# Best method: cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499
# Best AUC: 0.8014113537977174
# <AxesSubplot:>

# %% [markdown]
# ## valid3

# %%
dataset = "valid3"
cv_model_names =["cellpose_data_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499",
                 "cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499"
                 ]
train_test_auc(cv_model_names, target_dir, dataset,  thresholds=thresholds,
               n_folds=n_folds, stitch_threshold=stitch_threshold, anisotropy=anisotropy)
# Out:
# Best method: cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499
# Best AUC: 0.7942217630853995
# <AxesSubplot:>

# %%
# joint datasets
dataset = ["valid1", "valid2", "valid3"]

cv_model_names =["cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499"
                 ]
ax, aps_train, aps_test = train_test_auc(cv_model_names,
                                         target_dir,
                                         dataset,
                                         thresholds=thresholds,
                                         n_folds=n_folds,
                                         stitch_threshold=stitch_threshold,
                                         anisotropy=anisotropy,
                                         return_metrics=True)

plt.savefig(os.path.join(fig_path,
                         "metric_RBC_before_pp.pdf"),
            bbox_inches='tight',
            pad_inches=0,
            dpi=200)

np.save(os.path.join(fig_path, "metric_RBC_before_pp_split_fold_threshold.npy"),
        np.array(np.concatenate([aps_train, aps_test])))
# Out:
# Best method: cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499
# Best AUC: 0.8050633234009857

# %% [markdown]
# # 2D vs 3D

# %%
dataset = ["valid1", "valid2", "valid3"]
cv_model_names =["cellpose_data_valid1_valid2_valid3_by_stack_mode_2D_min_train_masks_0_seed_0_epoch_499",
                 "cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499"
                 ]


ax = train_test_auc(cv_model_names, target_dir, dataset,  thresholds=thresholds,
               n_folds=n_folds, stitch_threshold=stitch_threshold, anisotropy=anisotropy)
# Out:
# Best method: cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499
# Best AUC: 0.8050633234009857

# %% [markdown]
# # CV vs full model

# %%
dataset = ["valid1", "valid2", "valid3"]
cv_model_names =["cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499"
                 ]

full_model_names = ["cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499"]

ax = train_test_auc(cv_model_names, target_dir, dataset,  thresholds=thresholds,
               n_folds=n_folds, stitch_threshold=stitch_threshold, anisotropy=anisotropy)

ax = train_test_auc(full_model_names, target_dir, dataset,  thresholds=thresholds,
               n_folds=1, stitch_threshold=stitch_threshold, anisotropy=anisotropy, ax=ax, cmap_name="Set1")
# Out:
# Best method: cellpose_data_valid1_valid2_valid3_by_stack_mode_3D_iso_min_train_masks_0_seed_0_epoch_499
# Best AUC: 0.8050633234009857
